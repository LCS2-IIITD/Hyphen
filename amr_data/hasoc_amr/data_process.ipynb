# %%
# !pip install transformers

# %%
# !pip install sentencepiece

# %%
! /opt/bin/nvidia-smi

# %%
cd /content/drive/MyDrive/hasoc2021/Data/task1_data/subtask1-B

# %%
# !python sub-B_data_process.py

# %%
#xiaofeng

# %%
cd /content/drive/MyDrive/hasoc2021/subtask1-B/HI/B_hi-mrberta+Bilstm

# %%
# !python hi_mbert+Bilstm.py

# %%
cd /content/drive/MyDrive/hasoc2021/subtask1-A/HI/mBert

# %%
# !python hi_mbert_textcnn.py

# %%
cd /content/drive/MyDrive/hasoc2021/subtask1-B/EN/B_en-Deberta+Bilstm

# %%
# !python en_deberta+bilstm.py

# %%
cd /content/drive/MyDrive/hasoc2021/Data/task1_data/subtask1-B

# %%
# !python sub-B_data_process.py

# %%
cd /content/drive/MyDrive/hasoc2021/subtask1-B/EN/B_en-Deberta+Bilstm

# %%
# !python en_deberta+bilstm.py

# %%
cd /content/drive/MyDrive/hasoc2021/subtask1-B/HI/B_hi-mrberta+Bilstm

# %%
# !python hi_mbert+Bilstm.py

# %%
cd /content/drive/MyDrive/hasoc2021/Data/task1_data/subtask1-B

# %%
# !python mr_bert_rnn.py

# %%
cd /content/drive/MyDrive/hasoc2021/subtask1-B/EN/B_en-Deberta+Bilstm

# %%
# !python en_deberta+bilstm.py
# Out:
# Downloading: 100% 728/728 [00:00<00:00, 959kB/s]
# Downloading: 100% 557M/557M [00:08<00:00, 62.4MB/s]
# Reading validation data...
# Downloading: 100% 52.0/52.0 [00:00<00:00, 65.8kB/s]
# Downloading: 100% 899k/899k [00:00<00:00, 2.93MB/s]
# Downloading: 100% 456k/456k [00:00<00:00, 1.49MB/s]
# Validation Accuracy: 0.7356004901960784  F1_Macro: 0.6051067382215968
# ------------------------------------------
# Reading test data...
# ==================== loading models to test... =====================
# -----Testing-----
# 100% 21/21 [00:10<00:00,  1.93it/s]
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# ...

# %%
cd /content/drive/MyDrive/hasoc2021/subtask1-B/HI/B_hi-mrberta+Bilstm

# %%
# !python hi_mbert+Bilstm.py

# %%
cd /content/drive/MyDrive/HASOC2021/Data/task1_data/subtask1-A

# %%
# !python sub-A_data_process.py

# %%
cd /content/drive/MyDrive/HASOC2021/Data/task1_data/subtask1-B

# %%
# !python sub-B_data_process.py

# %%
#task2 data_process

# %%
cd /content/drive/MyDrive/HASOC2021/process_data/task2_data_process

# %%
# !python data_clearning.py

# %%
# !python task2_delete_no_Offensive.py

# %%
# !python train_test_split.py

# %%
cd /content/drive/MyDrive/HASOC2021/subtask1-B/HI/Deberta

# %%
# !python hi_deberta.py

# %%
cd /content/drive/MyDrive/hasoc2021/subtask1-B/HI/B_hi-mrberta+Bilstm

# %%
# !python hi_mbert+Bilstm.py
# Out:
# Downloading: 100% 953/953 [00:00<00:00, 1.28MB/s]
# Downloading: 100% 669M/669M [00:10<00:00, 61.1MB/s]
# Reading training data...
# Downloading: 100% 39.0/39.0 [00:00<00:00, 43.8kB/s]
# Downloading: 100% 872k/872k [00:00<00:00, 2.79MB/s]
# Downloading: 100% 112/112 [00:00<00:00, 120kB/s]
# ------------------------------------------
# Reading validation data...
# -----Training-----
# Epoch 1
#   0% 0/156 [00:00<?, ?it/s]0 1.3780425786972046
# Validation Accuracy: 0.6236842105263158  F1_Macro: 0.20987686980995096
# The best models has been saved
#   1% 1/156 [00:54<2:20:09, 54.26s/it]1 1.3246628046035767
#   1% 2/156 [00:56<1:00:52, 23.72s/it]2 1.2420692443847656
#   2% 3/156 [00:58<35:29, 13.92s/it]  3 1.1758241653442383
#   3% 4/156 [01:01<23:36,  9.32s/it]4 1.169386863708496
#   3% 5/156 [01:03<17:04,  6.78s/it]5 1.1727972030639648
#   4% 6/156 [01:05<13:07,  5.25s/it]6 1.1366835832595825
#   4% 7/156 [01:07<10:38,  4.29s/it]7 1.2397667169570923
# ...
